# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52506/23CSBTB50/blob/main/Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/Salary_Data (2).csv')
print(data);
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y=data['Salary']
print(y);
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x=data.drop('Salary',axis=1)
print(x);
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data)
print(data_normalized)
# Out:
# [[0.         0.01904087]
#  [0.0212766  0.1000945 ]
#  [0.04255319 0.        ]
#  [0.09574468 0.06843846]
#  [0.11702128 0.02551382]
#  [0.19148936 0.22337586]
#  [0.20212766 0.26481219]
#  [0.22340426 0.19742499]
#  [0.22340426 0.31554453]
#  [0.27659574 0.229837  ]
#  [0.29787234 0.30105126]
#  [0.30851064 0.21335932]
#  [0.30851064 0.22709662]
#  [0.31914894 0.2285613 ]
#  [0.36170213 0.27616348]
#  [0.40425532 0.35680369]
#  [0.42553191 0.33425467]
#  [0.44680851 0.53575478]
#  [0.5106383  0.51537916]
#  [0.5212766  0.66393811]
#  [0.60638298 0.63792818]
#  [0.63829787 0.7151193 ]
#  [0.72340426 0.75089771]
#  [0.75531915 0.89866525]
#  [0.80851064 0.84691708]
#  [0.84042553 0.80145287]
#  [0.89361702 0.93595559]
#  [0.90425532 0.88476258]
#  [0.9787234  1.        ]
#  [1.         0.9938696 ]]

# %%
import pandas as pd
data=pd.read_csv('/content/diabetes_data_upload.csv')
print(data)
print(data.columns)
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
y=data['class']
print(y);
# Out:
# 0      Positive
# 1      Positive
# 2      Positive
# 3      Positive
# 4      Positive
#          ...
# 515    Positive
# 516    Positive
# 517    Positive
# 518    Negative
# 519    Negative
# Name: class, Length: 520, dtype: object

# %%
x=data.drop('class',axis=1)
print(x)
x = x.drop('Obesity', axis=1)
print(x)
# Out:
#           Age  Gender Polyuria Polydipsia sudden weight loss weakness  \
# 0    0.324324    Male       No        Yes                 No      Yes
# 1    0.567568    Male       No         No                 No      Yes
# 2    0.337838    Male      Yes         No                 No      Yes
# 3    0.391892    Male       No         No                Yes      Yes
# 4    0.594595    Male      Yes        Yes                Yes      Yes
# ..        ...     ...      ...        ...                ...      ...
# 515  0.310811  Female      Yes        Yes                Yes       No
# 516  0.432432  Female      Yes        Yes                Yes      Yes
# 517  0.567568  Female      Yes        Yes                Yes      Yes
# 518  0.216216  Female       No         No                 No      Yes
# 519  0.351351    Male       No         No                 No       No
#
#     Polyphagia Genital thrush visual blurring Itching Irritability  \
# ...

# %%
features = data.columns[:-1]
target = data.columns[-1]
print("Features:", features)
print("Target Variable:", target)
# Out:
# Features: Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity'],
#       dtype='object')
# Target Variable: class

# %%
for feature in features:
  plt.figure(figsize=(8, 6))
  plt.scatter(data[feature], data[target], alpha=0.5)
  plt.title(f'{feature} vs {target}')
  plt.xlabel(feature)
  plt.ylabel(target)
  plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
for column in data.select_dtypes(include=['object']).columns:
  label_encoders[column] = LabelEncoder()
data[column] = label_encoders[column].fit_transform(data[column])
print(data.head())
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity  class
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
numerical_features = data[features].select_dtypes(include=['number'])
data[numerical_features.columns] = scaler.fit_transform(numerical_features)
print(data.head())
# Out:
#         Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0  0.324324   Male       No        Yes                 No      Yes         No
# 1  0.567568   Male       No         No                 No      Yes         No
# 2  0.337838   Male      Yes         No                 No      Yes        Yes
# 3  0.391892   Male       No         No                Yes      Yes        Yes
# 4  0.594595   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity  class
# ...
